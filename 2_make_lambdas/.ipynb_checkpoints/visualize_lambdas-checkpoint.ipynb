# %%
import matplotlib as mpl
import matplotlib.pyplot as plt #pyplot is a sub-module of matplotlib which doesn't get imported with a simple import matplotlib.
import numpy as np

# %%
path = "/Users/douglas/Documents/Features Transfer/store lambdas/"
savepath = "/Users/douglas/Documents/Features Transfer/figures/"
directory = 197 #directory number
Lambdas = np.loadtxt(path+"lambdas"+str(directory)+".txt",delimiter=",")

# %%
# setup to plot lambdas

# interaction alphas from the MiChroM for a couple type-to-type interactions
A1B1 = -0.262513 #smallest magnitude, but farthest right on a number line
A1A1 = -0.268028
B1B1 = -0.342020
vmax = A1B1
vmin = B1B1

#Colormaps map the data to be plotted into the range [0,1]. I need the mapped number associated with A1A1.
special_number_for_A1A1 = (A1A1-vmin)/(vmax-vmin)
print("special_number_for_A1A1 =",special_number_for_A1A1)

nodes = [0,special_number_for_A1A1,1]
# Out:
# special_number_for_A1A1 = 0.9306350384242897

# %%
# Plot lambdas

# Make a colormap to distinguish the three type-to-type interactions by color.
colors = ['royalblue','skyblue','white']
#colors = ['black','lightgray','white']
my_cmap = mpl.colors.LinearSegmentedColormap.from_list("my_cmap", list(zip(nodes,colors)))

for spine in plt.gca().spines.values():#Removes the frame box
    spine.set_visible(False)

plt.box('False')
plt.imshow(Lambdas,vmin=vmin,vmax =vmax,cmap=my_cmap) 
plt.colorbar()
plt.tick_params(left = False, right = False , labelleft = False , labelbottom = False, bottom = False)#Remove ticks and axis labels.
plt.savefig(savepath+"lambdas"+str(directory)+".pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yg/xmt_zsl154zd8l51xlg5s_s40000gn/T/ipykernel_8778/1811693336.py in <module>
#       4 colors = ['RoyalBlue1','skyblue','white']
#       5 #colors = ['black','lightgray','white']
# ----> 6 my_cmap = mpl.colors.LinearSegmentedColormap.from_list("my_cmap", list(zip(nodes,colors)))
#       7
#       8 for spine in plt.gca().spines.values():#Removes the frame box
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in from_list(name, colors, N, gamma)
#     954             vals = np.linspace(0, 1, len(colors))
#     955
# --> 956         r, g, b, a = to_rgba_array(colors).T
#     957         cdict = {
#     958             "red": np.column_stack([vals, r, r]),
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     373             rgba = np.array(c)
#     374         else:
# --> 375             rgba = np.array([to_rgba(cc) for cc in c])
#     376     else:
#     377         rgba = np.array([to_rgba(cc) for cc in c])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in <listcomp>(.0)
#     373             rgba = np.array(c)
#     374         else:
# --> 375             rgba = np.array([to_rgba(cc) for cc in c])
#     376     else:
#     377         rgba = np.array([to_rgba(cc) for cc in c])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     185         rgba = None
#     186     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 187         rgba = _to_rgba_no_colorcycle(c, alpha)
#     188         try:
#     189             _colors_full_map.cache[c, alpha] = rgba
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     260                     f"Value must be within 0-1 range")
#     261             return c, c, c, alpha if alpha is not None else 1.
# --> 262         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     263     # turn 2-D array into 1-D array
#     264     if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: 'RoyalBlue1'

# %%
# Plot lambdas

# Make a colormap that doesn't distinguish the three type-to-type interactions by color.
colors = ['royalblue','white']
#colors = ['black','white']
my_cmap = mpl.colors.LinearSegmentedColormap.from_list("my_cmap", list(zip([0,1],colors)))

for spine in plt.gca().spines.values():#Removes the frame box
    spine.set_visible(False)
    
plt.imshow(Lambdas,vmin=vmin,vmax =vmax,cmap=my_cmap) 
plt.colorbar()
plt.tick_params(left = False, right = False , labelleft = False , labelbottom = False, bottom = False)#Remove ticks and axis labels.
plt.savefig(savepath+"lambdas"+str(directory)+".pdf")
plt.show()
