# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ### Fits to MiChroM optimization from MiChroM supplement

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Translate the above functions into python
def gamma_exp(d, A=1.969, B=2.433, C=-.015):
    return -A*np.exp(-d/B)+C

def gamma_2(d, A=0.056, B= 4.764):
    return -A/np.log(d)-B/d**2

def gamma_3(d, A=0.030, B=0.351, C=3.727):
    return -A/np.log(d)-B/d-C/d**2

# %% [markdown]
# ### Reparametrize fits to make gammas

# %%
d = np.array(range(2500))
bead_size = .5 # kilobases

# %%
i = 112 # number of first
for A in [.25,.3]:
    for B in [800,1200,2000,3000]:
        for C in [0.0]:
            gamma_i = gamma_exp(d,A,B,C)
            np.savetxt(f'gamma_files/gamma_{i}.txt',gamma_i)
            plt.plot(bead_size*d,gamma_i,label=f'sim {i}  A={A}  B={B}  C={C}')
            i += 1
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d')
plt.ylabel('gamma')
plt.show()

# %%
gamma_122_cis = gamma_exp(d,A=.2,B=1600,C=0.0)
gamma_122_trans = gamma_exp(d,A=.2,B=400,C=0.0)
np.savetxt('gamma_files/gamma_122_cis.txt',gamma_122_cis)
np.savetxt('gamma_files/gamma_122_trans.txt',gamma_122_trans)
plt.plot(bead_size*d,gamma_122_cis,label='sim_122_cis  A=.2  B=1600  C=0')
plt.plot(bead_size*d,gamma_122_trans,label='sim_122_trans  A=.2  B=400  C=0')
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d')
plt.ylabel('gamma')
plt.show()

# %%
i = 123 # number of first
A = .2
B_cis = 800
C = 0.0
gamma_123_to_126_cis = gamma_exp(d,A,B_cis,C)
np.savetxt('gamma_files/gamma_123_to_126_cis.txt',gamma_123_to_126_cis)
plt.plot(bead_size*d,gamma_123_to_126_cis,label=f'sim 123-126 cis   A={A}  B={B_cis}  C={C}')
for B_trans in [200,100,50,25]:
    gamma_i_trans = gamma_exp(d,A,B_trans,C)
    np.savetxt(f'gamma_files/gamma_{i}_trans.txt',gamma_i_trans)
    plt.plot(bead_size*d,gamma_i_trans,label=f'sim {i} trans   A={A}  B={B_trans}  C={C}')
    i += 1
plt.plot()
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d (kb)')
plt.xlim(0,400)
plt.ylabel('gamma')
plt.show()

# %%
i = 127 # number of first
for A in [.1,.2,.3,.4,.5,.6,.7,.8]:
    for B in [25]:
        for C in [0.0]:
            gamma_i = gamma_exp(d,A,B,C)
            np.savetxt(f'gamma_files/gamma_{i}.txt',gamma_i)
            plt.plot(bead_size*d,gamma_i,label=f'sim {i}  A={A}  B={B}  C={C}')
            i += 1
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d')
plt.xlim(0,40)
plt.ylabel('gamma')
plt.show()

# %%
i = 135 # number of first
for A in [.2]:
    for B in [1200]:
        for C in [-0.1,-.2,-.3,-.4,-.5,-.6,-.7,-.8]:
            gamma_i = gamma_exp(d,A,B,C)
            np.savetxt(f'gamma_files/gamma_{i}.txt',gamma_i)
            plt.plot(bead_size*d,gamma_i,label=f'sim {i}  A={A}  B={B}  C={C}')
            i += 1
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d')
plt.xlim(0,2000)
plt.ylabel('gamma')
plt.show()

# %%
i = 143 # number of first
gamma_143_to_150_cis = gamma_exp(d,A=.2,B=800,C=0.0)
np.savetxt('gamma_files/gamma_143_to_150_cis.txt', gamma_143_to_150_cis)
for A in [.25,.3,.4,.5]:
    for B in [25,50]:
        for C in [0.0]:
            gamma_trans_i = gamma_exp(d,A,B,C)
            np.savetxt(f'gamma_files/gamma_trans_{i}.txt',gamma_trans_i)
            plt.plot(bead_size*d,gamma_trans_i,label=f'sim {i} trans  A={A}  B={B}  C={C}')
            i += 1
plt.plot(bead_size*d,gamma_143_to_150_cis,label='cis A=.2  B=800  C=0.0')
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d')
plt.xlim(0,60)
plt.ylabel('gamma')
plt.show()

# %%
i = 151 # number of first
gamma_old = gamma_exp(d,C=0)
gamma_trans_151_to_158 = gamma_exp(d,A=2,B=2.5,C=0.0)
for A in [.2,.3]:
    for B in [100,300,900,2700]:
        for C in [0.0]:
            gamma_cis_i = gamma_exp(d,A,B,C)
            np.savetxt(f'gamma_files/gamma_{i}_cis.txt',gamma_cis_i)
            plt.plot(bead_size*d,gamma_cis_i,label=f'sim {i} cis  A={A}  B={B}  C={C}')
            i += 1
np.savetxt('gamma_files/gamma_trans_151_to_158.txt',gamma_trans_151_to_158)
plt.plot(bead_size*d,gamma_trans_151_to_158,label='trans  A=2  B=2.5  C=0.0')
plt.plot(bead_size*d,gamma_old,'-',label='old')
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d (kb)')
#plt.xlim(0,60)
plt.ylabel('gamma')
plt.ylim(-.5,0.01)
plt.show()

# %%
i = 159 # number of the first sim in this batch
gamma_159_to_166_cis = gamma_exp(d, A=.2, B=2700, C=0.0)
np.savetxt('gamma_files/gamma_159_to_166_cis.txt', gamma_159_to_166_cis)
for A in [2, 1.5, 1, .5]:
    for B in [2.5,5]:
        for C in [0.0]:
            gamma_trans_i = gamma_exp(d,A,B,C)
            np.savetxt(f'gamma_files/gamma_trans_{i}.txt',gamma_trans_i)
            plt.plot(bead_size*d,gamma_trans_i,label=f'sim {i} trans  A={A}  B={B}  C={C}')
            i += 1
plt.plot(bead_size*d,gamma_159_to_166_cis,label='     cis  A=.2 B=2700 C=0.0')
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d')
plt.xlim(0,10)
plt.ylabel('gamma')
plt.show()

# %%
i = 175 # number of the first sim in this batch
gamma_phase_diagram_cis = gamma_exp(d, A=.2, B=2700, C=0.0)
np.savetxt('gamma_files/gamma_phase_diagram_cis.txt', gamma_phase_diagram_cis)
for A in [.4,.5,.6,.7,.8,.9,1]:
    for B in [.5,1,1.5,2,2.5,3,3.5]:
        for C in [0.0]:
            gamma_trans_i = gamma_exp(d,A,B,C)
            np.savetxt(f'gamma_files/gamma_trans_{i}.txt',gamma_trans_i)
            plt.plot(bead_size*d,gamma_trans_i,label=f'sim {i} trans  A={A}  B={B}  C={C}')
            print(f'sim {i} trans  A={A}  B={B}  C={C}')
            i += 1
plt.plot(bead_size*d, gamma_phase_diagram_cis, label='     cis  A=.2 B=2700  C={C}')
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d')
plt.xlim(0,10)
plt.ylabel('gamma')
plt.show()
# Out:
# sim 175 trans  A=0.4  B=0.5  C=0.0
# sim 176 trans  A=0.4  B=1  C=0.0
# sim 177 trans  A=0.4  B=1.5  C=0.0
# sim 178 trans  A=0.4  B=2  C=0.0
# sim 179 trans  A=0.4  B=2.5  C=0.0
# sim 180 trans  A=0.4  B=3  C=0.0
# sim 181 trans  A=0.4  B=3.5  C=0.0
# sim 182 trans  A=0.5  B=0.5  C=0.0
# sim 183 trans  A=0.5  B=1  C=0.0
# sim 184 trans  A=0.5  B=1.5  C=0.0
# sim 185 trans  A=0.5  B=2  C=0.0
# sim 186 trans  A=0.5  B=2.5  C=0.0
# sim 187 trans  A=0.5  B=3  C=0.0
# sim 188 trans  A=0.5  B=3.5  C=0.0
# sim 189 trans  A=0.6  B=0.5  C=0.0
# sim 190 trans  A=0.6  B=1  C=0.0
# sim 191 trans  A=0.6  B=1.5  C=0.0
# sim 192 trans  A=0.6  B=2  C=0.0
# sim 193 trans  A=0.6  B=2.5  C=0.0
# sim 194 trans  A=0.6  B=3  C=0.0
# sim 195 trans  A=0.6  B=3.5  C=0.0
# sim 196 trans  A=0.7  B=0.5  C=0.0
# sim 197 trans  A=0.7  B=1  C=0.0
# sim 198 trans  A=0.7  B=1.5  C=0.0
# sim 199 trans  A=0.7  B=2  C=0.0
# sim 200 trans  A=0.7  B=2.5  C=0.0
# sim 201 trans  A=0.7  B=3  C=0.0
# ...

# %%
gamma_cis_224 = np.zeros(2500)
gamma_trans_224 = gamma_exp(d, A=.2, B=2700, C=0.0)
np.savetxt('gamma_files/gamma_cis_224.txt', gamma_cis_224)
np.savetxt('gamma_files/gamma_trans_224.txt', gamma_trans_224)
plt.plot(bead_size*d, gamma_cis_224, label='     cis  gamma = 0 ')
plt.plot(bead_size*d, gamma_trans_224, label='     trans  A=.2  B=2700  C=0')
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d (kb)')
#plt.xlim(0,10)
plt.ylabel('gamma')
plt.show()

# %%
i = 225 # number of the first sim in this batch
gamma_phase_diagram_cis = gamma_exp(d, A=.2, B=2700, C=0.0)
np.savetxt('gamma_files/gamma_phase_diagram_cis.txt', gamma_phase_diagram_cis)
for A in [1.1, 1.2, 1.3, 1.4, 1.5, 1.6]:
    for B in [.5,1,1.5,2,2.5,3,3.5]:
        for C in [0.0]:
            gamma_trans_i = gamma_exp(d,A,B,C)
            np.savetxt(f'gamma_files/gamma_trans_{i}.txt',gamma_trans_i)
            plt.plot(bead_size*d,gamma_trans_i,label=f'sim {i} trans  A={A}  B={B}  C={C}')
            print(f'sim {i} trans  A={A}  B={B}  C={C}')
            i += 1
plt.plot(bead_size*d, gamma_phase_diagram_cis, label='     cis  A=.2 B=2700  C={C}')
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d')
plt.xlim(0,10)
plt.ylabel('gamma')
plt.show()
# Out:
# sim 225 trans  A=1.1  B=0.5  C=0.0
# sim 226 trans  A=1.1  B=1  C=0.0
# sim 227 trans  A=1.1  B=1.5  C=0.0
# sim 228 trans  A=1.1  B=2  C=0.0
# sim 229 trans  A=1.1  B=2.5  C=0.0
# sim 230 trans  A=1.1  B=3  C=0.0
# sim 231 trans  A=1.1  B=3.5  C=0.0
# sim 232 trans  A=1.2  B=0.5  C=0.0
# sim 233 trans  A=1.2  B=1  C=0.0
# sim 234 trans  A=1.2  B=1.5  C=0.0
# sim 235 trans  A=1.2  B=2  C=0.0
# sim 236 trans  A=1.2  B=2.5  C=0.0
# sim 237 trans  A=1.2  B=3  C=0.0
# sim 238 trans  A=1.2  B=3.5  C=0.0
# sim 239 trans  A=1.3  B=0.5  C=0.0
# sim 240 trans  A=1.3  B=1  C=0.0
# sim 241 trans  A=1.3  B=1.5  C=0.0
# sim 242 trans  A=1.3  B=2  C=0.0
# sim 243 trans  A=1.3  B=2.5  C=0.0
# sim 244 trans  A=1.3  B=3  C=0.0
# sim 245 trans  A=1.3  B=3.5  C=0.0
# sim 246 trans  A=1.4  B=0.5  C=0.0
# sim 247 trans  A=1.4  B=1  C=0.0
# sim 248 trans  A=1.4  B=1.5  C=0.0
# sim 249 trans  A=1.4  B=2  C=0.0
# sim 250 trans  A=1.4  B=2.5  C=0.0
# sim 251 trans  A=1.4  B=3  C=0.0
# ...

# %%
i = 267 # number of the first sim in this batch
gamma_phase_diagram_cis = gamma_exp(d, A=.2, B=2700, C=0.0)
np.savetxt('gamma_files/gamma_phase_diagram_cis.txt', gamma_phase_diagram_cis)
for A in [.4,.5,.6,.7,.8,.9,1]:
    for B in [4,4.5,5,5.5,6,6.5]:
        for C in [0.0]:
            gamma_trans_i = gamma_exp(d,A,B,C)
            np.savetxt(f'gamma_files/gamma_trans_{i}.txt',gamma_trans_i)
            plt.plot(bead_size*d,gamma_trans_i,label=f'sim {i} trans  A={A}  B={B}  C={C}')
            print(f'sim {i} trans  A={A}  B={B}  C={C}')
            i += 1
plt.plot(bead_size*d, gamma_phase_diagram_cis, label='     cis  A=.2  B=2700  C={C}')
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d')
plt.xlim(0,10)
plt.ylabel('gamma')
plt.show()
# Out:
# sim 267 trans  A=0.4  B=4  C=0.0
# sim 268 trans  A=0.4  B=4.5  C=0.0
# sim 269 trans  A=0.4  B=5  C=0.0
# sim 270 trans  A=0.4  B=5.5  C=0.0
# sim 271 trans  A=0.4  B=6  C=0.0
# sim 272 trans  A=0.4  B=6.5  C=0.0
# sim 273 trans  A=0.5  B=4  C=0.0
# sim 274 trans  A=0.5  B=4.5  C=0.0
# sim 275 trans  A=0.5  B=5  C=0.0
# sim 276 trans  A=0.5  B=5.5  C=0.0
# sim 277 trans  A=0.5  B=6  C=0.0
# sim 278 trans  A=0.5  B=6.5  C=0.0
# sim 279 trans  A=0.6  B=4  C=0.0
# sim 280 trans  A=0.6  B=4.5  C=0.0
# sim 281 trans  A=0.6  B=5  C=0.0
# sim 282 trans  A=0.6  B=5.5  C=0.0
# sim 283 trans  A=0.6  B=6  C=0.0
# sim 284 trans  A=0.6  B=6.5  C=0.0
# sim 285 trans  A=0.7  B=4  C=0.0
# sim 286 trans  A=0.7  B=4.5  C=0.0
# sim 287 trans  A=0.7  B=5  C=0.0
# sim 288 trans  A=0.7  B=5.5  C=0.0
# sim 289 trans  A=0.7  B=6  C=0.0
# sim 290 trans  A=0.7  B=6.5  C=0.0
# sim 291 trans  A=0.8  B=4  C=0.0
# sim 292 trans  A=0.8  B=4.5  C=0.0
# sim 293 trans  A=0.8  B=5  C=0.0
# ...

# %%
i = 309 # number of the first sim in this batch
gamma_phase_diagram_cis = gamma_exp(d, A=.2, B=2700, C=0.0)
np.savetxt('gamma_files/gamma_phase_diagram_cis.txt', gamma_phase_diagram_cis)
for A in [1.1,1.2,1.3,1.4,1.5,1.6]:
    for B in [4,4.5,5,5.5,6,6.5]:
        for C in [0.0]:
            gamma_trans_i = gamma_exp(d,A,B,C)
            np.savetxt(f'gamma_files/gamma_trans_{i}.txt',gamma_trans_i)
            plt.plot(bead_size*d,gamma_trans_i,label=f'sim {i} trans  A={A}  B={B}  C={C}')
            print(f'sim {i} trans  A={A}  B={B}  C={C}')
            i += 1
plt.plot(bead_size*d, gamma_phase_diagram_cis, label='     cis  A=.2 B=2700  C={C}')
plt.legend(title = 'A e **(-d/B)+C')
plt.xlabel('genomic distance d')
plt.xlim(0,10)
plt.ylabel('gamma')
plt.show()
# Out:
# sim 309 trans  A=1.1  B=4  C=0.0
# sim 310 trans  A=1.1  B=4.5  C=0.0
# sim 311 trans  A=1.1  B=5  C=0.0
# sim 312 trans  A=1.1  B=5.5  C=0.0
# sim 313 trans  A=1.1  B=6  C=0.0
# sim 314 trans  A=1.1  B=6.5  C=0.0
# sim 315 trans  A=1.2  B=4  C=0.0
# sim 316 trans  A=1.2  B=4.5  C=0.0
# sim 317 trans  A=1.2  B=5  C=0.0
# sim 318 trans  A=1.2  B=5.5  C=0.0
# sim 319 trans  A=1.2  B=6  C=0.0
# sim 320 trans  A=1.2  B=6.5  C=0.0
# sim 321 trans  A=1.3  B=4  C=0.0
# sim 322 trans  A=1.3  B=4.5  C=0.0
# sim 323 trans  A=1.3  B=5  C=0.0
# sim 324 trans  A=1.3  B=5.5  C=0.0
# sim 325 trans  A=1.3  B=6  C=0.0
# sim 326 trans  A=1.3  B=6.5  C=0.0
# sim 327 trans  A=1.4  B=4  C=0.0
# sim 328 trans  A=1.4  B=4.5  C=0.0
# sim 329 trans  A=1.4  B=5  C=0.0
# sim 330 trans  A=1.4  B=5.5  C=0.0
# sim 331 trans  A=1.4  B=6  C=0.0
# sim 332 trans  A=1.4  B=6.5  C=0.0
# sim 333 trans  A=1.5  B=4  C=0.0
# sim 334 trans  A=1.5  B=4.5  C=0.0
# sim 335 trans  A=1.5  B=5  C=0.0
# ...
