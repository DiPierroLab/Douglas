# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "/Users/douglas/Documents/Features_Transfer/store_lambdas/"
savepath = "/Users/douglas/Documents/Features_Transfer/figures/lambdas_images/"

# %%
directory_numbers = [Lambdas[0,2]]
for i in directory_numbers:
    Lambdas = np.loadtxt(path+f'lambdas{i}.txt',delimiter=",")
    plt.matshow(Lambdas,vmin=-0.3338519067079908,vmax =Lambdas[0,4999],cmap='Blues_r') 
    plt.colorbar()
    plt.savefig(savepath+f'lambdas{i}.svg')
    plt.title(f'lambdas{i}')
    plt.show()

# %%
# Out:
# -0.3338519067079908
