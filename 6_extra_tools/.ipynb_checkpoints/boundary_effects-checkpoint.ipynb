# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
HiC69 = np.loadtxt("/Users/douglas/Documents/Features Transfer/store Hi-C data/Hi-C_directory_69.txt")
N = 2500
plt.imshow(np.log(HiC69))
plt.show()
plt.imshow(np.log(HiC69[N+1:N+626,N+1876:N+2501]))#top right square on the cis maternal map (22 block)
plt.show()
plt.imshow(np.log(HiC69[N+626:N+1251-200,N+1251+200:N+1876]))
plt.show()
